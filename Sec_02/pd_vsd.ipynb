# %%
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
pwd
# Out:
# 'd:\\AHT_Course\\PythonCourse\\Sec_02'

# %%
df1 = sns.load_dataset('tips')

# %%
df2 = pd.read_csv('D:/AHT_Course/PythonCourse/dataset/ece.csv')

# %%
df2.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1       ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2       ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3       ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4       ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
#
#    Magnitude                                        Subject  \
# 0          6  Electronic Card Transactions (ANZSIC06) - ECT
# 1          6  Electronic Card Transactions (ANZSIC06) - ECT
# 2          6  Electronic Card Transactions (ANZSIC06) - ECT
# 3          6  Electronic Card Transactions (ANZSIC06) - ECT
# 4          6  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# ...

# %%
x1 = np.random.rand(100, 5)

# %%
x2 = np.random.rand(10, 5)

# %%
df3 = pd.DataFrame(x1, columns= ['a', 'b', 'c', 'd', 'e'])
df3
# Out:
#            a         b         c         d         e
# 0   0.416248  0.515092  0.531247  0.041472  0.830754
# 1   0.588872  0.167617  0.571802  0.594754  0.733733
# 2   0.133309  0.145209  0.067515  0.856420  0.681652
# 3   0.452238  0.923148  0.639453  0.675406  0.338831
# 4   0.779023  0.235718  0.241565  0.310711  0.794070
# ..       ...       ...       ...       ...       ...
# 95  0.727722  0.514006  0.135557  0.985707  0.814432
# 96  0.330080  0.110089  0.953150  0.787795  0.140914
# 97  0.860271  0.021982  0.779353  0.161363  0.005405
# 98  0.289313  0.840037  0.507841  0.158839  0.567426
# 99  0.965579  0.672989  0.671347  0.995756  0.519449
#
# [100 rows x 5 columns]

# %%
df4 = pd.DataFrame(x2, columns= ['a', 'b', 'c', 'd', 'e'])
df4
# Out:
#           a         b         c         d         e
# 0  0.982396  0.807318  0.937356  0.088398  0.946814
# 1  0.775428  0.106794  0.305409  0.018652  0.026462
# 2  0.530563  0.007331  0.192917  0.984206  0.497580
# 3  0.448472  0.493527  0.963780  0.036068  0.116850
# 4  0.449374  0.308964  0.414606  0.147572  0.682409
# 5  0.469638  0.498950  0.577197  0.791424  0.503072
# 6  0.829431  0.004260  0.064196  0.520292  0.798227
# 7  0.937401  0.115907  0.791090  0.691328  0.991427
# 8  0.657150  0.854449  0.423583  0.632430  0.463374
# 9  0.423894  0.316063  0.378290  0.107227  0.847092

# %%
df3.plot.scatter(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df1.plot.scatter('total_bill', 'tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df4.plot.line()
# Out:
# <AxesSubplot:>

# %%
df3['c'].plot.line()
# Out:
# <AxesSubplot:>

# %%
df4.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4[['c','d']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df4.plot.area(alpha = 0.4)
# Out:
# <AxesSubplot:>

# %%
df4.plot.box()
# Out:
# <AxesSubplot:>

# %%
df1.plot.hexbin(x='total_bill', y='tip', gridsize=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
